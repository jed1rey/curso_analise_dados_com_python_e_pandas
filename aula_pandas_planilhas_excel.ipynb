# %%
#importando a biblioteca
import pandas as pd

# %%
#leitura dos arquivos
df1 = pd.read_excel("Aracaju.xlsx")
df2= pd.read_excel("Fortaleza.xlsx")
df3= pd.read_excel("Natal.xlsx")
df4= pd.read_excel("Recife.xlsx")
df5= pd.read_excel("Salvador.xlsx")

# %%
df1.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00    1520     1
# 1  Aracaju 2018-01-01   14.21    1522     6
# 2  Aracaju 2018-01-01   71.55    1520     1
# 3  Aracaju 2018-01-01    3.01    1521     7
# 4  Aracaju 2018-01-01   24.51    1522     8

# %%
#juntando todos os arquivos
df= pd.concat([df1,df2,df3,df4,df5])

# %%
#exibindo as 5 primeiras linhas
df.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00    1520     1
# 1  Aracaju 2018-01-01   14.21    1522     6
# 2  Aracaju 2018-01-01   71.55    1520     1
# 3  Aracaju 2018-01-01    3.01    1521     7
# 4  Aracaju 2018-01-01   24.51    1522     8

# %%
df.tail()
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde
# 235  Salvador 2019-01-03   41.84    1034     1
# 236  Salvador 2019-01-03  126.29    1035     3
# 237  Salvador 2019-01-03   38.06    1036     3
# 238  Salvador 2019-01-03  139.64    1035     1
# 239  Salvador 2019-01-03  161.41    1037     3

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas  LojaID  Qtde
# 191      Natal 2019-01-02  173.59    1034     2
# 178      Natal 2019-01-02   39.28    1037     3
# 117     Recife 2019-03-02   15.42     983     8
# 209      Natal 2019-01-02   69.98    1034     2
# 79   Fortaleza 2019-01-01   41.25    1005     6

# %%
#verificando o tipo de dado de cada coluna
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID             int64
# Qtde               int64
# dtype: object

# %%
#alterando o tipo de dado da coluna LojaID
df["lojaID"] = df["LojaID"].astype("object")

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID             int64
# Qtde               int64
# lojaID            object
# dtype: object

# %%
#consultando linhas com valores faltantes
df.isnull().sum()
# Out:
# Cidade    0
# Data      0
# Vendas    0
# LojaID    0
# Qtde      0
# lojaID    0
# dtype: int64

# %%
#substituindo os valores nulos pela média
df["Vendas"].fillna(df["Vendas"].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Cidade    0
# Data      0
# Vendas    0
# LojaID    0
# Qtde      0
# lojaID    0
# dtype: int64

# %%
df.sample(15)
# Out:
#         Cidade       Data  Vendas  LojaID  Qtde lojaID
# 103      Natal 2019-01-02  191.60    1034     1   1034
# 78   Fortaleza 2019-01-01   37.66    1005     2   1005
# 47     Aracaju 2018-01-01   80.46    1520     2   1520
# 6     Salvador 2019-01-01   36.30    1034     2   1034
# 19    Salvador 2019-01-01  167.12    1035     1   1035
# 186   Salvador 2019-01-02  169.09    1036     2   1036
# 126  Fortaleza 2019-03-02   41.87     980     8    980
# 13   Fortaleza 2019-02-12  118.58    1003     4   1003
# 188   Salvador 2019-01-02  178.11    1035     3   1035
# 163   Salvador 2019-01-02   17.66    1036     3   1036
# 159      Natal 2019-01-02  172.52    1035     1   1035
# 69   Fortaleza 2019-01-01  216.65    1003     6   1003
# 203      Natal 2019-01-02   37.75    1035     2   1035
# 56    Salvador 2019-01-01  178.44    1035     3   1035
# 167      Natal 2019-01-02   36.42    1037     1   1037

# %%
#substituindo os valores nulos por zero
df["Vendas"].fillna(0, inplace=True)

# %%
#apagando as linhas com valores nulos
df.dropna(inplace=True)

# %%
#apagando linhas com valores nulos com base apenas em 1 coluna
df.dropna(subset=["Vendas"],inplace=True)

# %%
#removendo linhas que estejam com valores faltantes em todas as colunas
df.dropna(how="all", inplace=True)

# %%
#criando a coluna receita
df["Receita"] = df["Vendas"].mul(df["Qtde"])

# %%
df.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde lojaID  Receita
# 0  Aracaju 2018-01-01  142.00    1520     1   1520   142.00
# 1  Aracaju 2018-01-01   14.21    1522     6   1522    85.26
# 2  Aracaju 2018-01-01   71.55    1520     1   1520    71.55
# 3  Aracaju 2018-01-01    3.01    1521     7   1521    21.07
# 4  Aracaju 2018-01-01   24.51    1522     8   1522   196.08

# %%
df.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde lojaID  Receita
# 0  Aracaju 2018-01-01  142.00    1520     1   1520   142.00
# 1  Aracaju 2018-01-01   14.21    1522     6   1522    85.26
# 2  Aracaju 2018-01-01   71.55    1520     1   1520    71.55
# 3  Aracaju 2018-01-01    3.01    1521     7   1521    21.07
# 4  Aracaju 2018-01-01   24.51    1522     8   1522   196.08

# %%
df["Receita/Vendas"] = df["Receita"] /df["Vendas"]

# %%
df.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde lojaID  Receita  Receita/Vendas
# 0  Aracaju 2018-01-01  142.00    1520     1   1520   142.00             1.0
# 1  Aracaju 2018-01-01   14.21    1522     6   1522    85.26             6.0
# 2  Aracaju 2018-01-01   71.55    1520     1   1520    71.55             1.0
# 3  Aracaju 2018-01-01    3.01    1521     7   1521    21.07             7.0
# 4  Aracaju 2018-01-01   24.51    1522     8   1522   196.08             8.0

# %%
#retornando a maior receita
df["Receita"].max()
# Out:
# 3544.0

# %%
#retornando menor receita
df["Receita"].min()
# Out:
# 3.34

# %%
#nlargest
df.nlargest(3, "Receita")
# Out:
#    Cidade       Data  Vendas  LojaID  Qtde lojaID  Receita  Receita/Vendas
# 7   Natal 2019-03-18   886.0     853     4    853   3544.0             4.0
# 51  Natal 2018-01-21   859.0     852     4    852   3436.0             4.0
# 55  Natal 2019-01-08   859.0     854     4    854   3436.0             4.0

# %%
#nsamllest
df.nsmallest(3,"Receita")
# Out:
#       Cidade       Data  Vendas  LojaID  Qtde lojaID  Receita  Receita/Vendas
# 118  Aracaju 2018-01-01    3.34    1522     1   1522     3.34             1.0
# 65    Recife 2019-01-01    4.01     981     1    981     4.01             1.0
# 92     Natal 2019-01-02    4.57    1035     1   1035     4.57             1.0

# %%
#Agrupamento por cidade
df.groupby("Cidade")["Receita"].sum()
# Out:
# Cidade
# Aracaju       48748.25
# Fortaleza     37913.97
# Natal        167227.52
# Recife        51936.51
# Salvador      40596.73
# Name: Receita, dtype: float64

# %%
#ordenando o conjunto de dados
df.sort_values("Receita", ascending=False).head(10)
# Out:
#    Cidade       Data  Vendas  LojaID  Qtde lojaID  Receita  Receita/Vendas
# 7   Natal 2019-03-18   886.0     853     4    853   3544.0             4.0
# 55  Natal 2019-01-08   859.0     854     4    854   3436.0             4.0
# 51  Natal 2018-01-21   859.0     852     4    852   3436.0             4.0
# 30  Natal 2018-10-02   856.0     853     4    853   3424.0             4.0
# 41  Natal 2018-05-20   835.0     852     4    852   3340.0             4.0
# 38  Natal 2018-02-25   828.0     852     4    852   3312.0             4.0
# 10  Natal 2018-10-27   828.0     852     4    852   3312.0             4.0
# 69  Natal 2019-03-24   817.0     852     4    852   3268.0             4.0
# 62  Natal 2018-02-10   793.0     854     4    854   3172.0             4.0
# 52  Natal 2018-04-27   778.0     854     4    854   3112.0             4.0

# %%
#transformando a coluna de data em tipo int
df["Data"] = df["Data"].astype("int64")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: casting datetime64[ns] values to int64 with .astype(...) is deprecated and will raise in a future version. Use .view(...) instead.

# %%
df.dtypes
# Out:
# Cidade             object
# Data                int64
# Vendas            float64
# LojaID              int64
# Qtde                int64
# lojaID             object
# Receita           float64
# Receita/Vendas    float64
# dtype: object

# %%
#transformando coluna de data em data
df["Data"] = pd.to_datetime(df["Data"])

# %%
#agrupando por ano
df.groupby(df["Data"].dt.year)["Receita"].sum()
# Out:
# Data
# 2018    118176.53
# 2019    228246.45
# Name: Receita, dtype: float64

# %%
#criando uma nova coluna com o ano
df["Ano_Venda"] = df["Data"].dt.year

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas  LojaID  Qtde lojaID  Receita  \
# 43       Natal 2019-04-01  538.00     853     3    853  1614.00
# 93   Fortaleza 2019-01-01   35.25    1003     5   1003   176.25
# 166   Salvador 2019-01-02  111.72    1035     3   1035   335.16
# 14     Aracaju 2018-01-01  148.21    1521     3   1521   444.63
# 51    Salvador 2019-01-01   13.37    1037     2   1037    26.74
#
#      Receita/Vendas  Ano_Venda
# 43              3.0       2019
# 93              5.0       2019
# 166             3.0       2019
# 14              3.0       2018
# 51              2.0       2019

# %%
#extraindo o mes e o dia
df["mes_venda"], df["dia_venda"] = (df["Data"].dt.month, df["Data"].dt.day)

# %%
df.sample(5)
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde lojaID  Receita  \
# 120  Salvador 2019-03-02  140.17    1036     2   1036   280.34
# 163  Salvador 2019-01-02   17.66    1036     3   1036    52.98
# 137  Salvador 2019-03-02   51.66    1036     3   1036   154.98
# 29    Aracaju 2018-01-01   44.04    1520     6   1520   264.24
# 73   Salvador 2019-01-01    8.39    1037     1   1037     8.39
#
#      Receita/Vendas  Ano_Venda  mes_venda  dia_venda
# 120             2.0       2019          3          2
# 163             3.0       2019          1          2
# 137             3.0       2019          3          2
# 29              6.0       2018          1          1
# 73              1.0       2019          1          1

# %%
#retornando a data mais antiga
df["Data"].min()
# Out:
# Timestamp('2018-01-01 00:00:00')

# %%
#calculando a diferenca de dias
df["diferenca_dias"] = df["Data"] - df["Data"].min()

# %%
df.sample(5)
# Out:
#       Cidade       Data  Vendas  LojaID  Qtde lojaID  Receita  Receita/Vendas  \
# 107   Recife 2019-01-01   15.40     980     7    980   107.80             7.0
# 25   Aracaju 2018-01-01   34.66    1521     8   1521   277.28             8.0
# 131   Recife 2019-03-02  139.07     982     6    982   834.42             6.0
# 67     Natal 2019-02-14  379.00     852     2    852   758.00             2.0
# 39     Natal 2019-01-10  504.00     854     3    854  1512.00             3.0
#
#      Ano_Venda  mes_venda  dia_venda diferenca_dias
# 107       2019          1          1       365 days
# 25        2018          1          1         0 days
# 131       2019          3          2       425 days
# 67        2019          2         14       409 days
# 39        2019          1         10       374 days

# %%
#criando a coluna trimestre
df["trimestre_venda"] = df["Data"].dt.quarter

# %%
df.sample()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde lojaID  Receita  Receita/Vendas  \
# 227  Natal 2019-01-02    14.7    1035     1   1035     14.7             1.0
#
#      Ano_Venda  mes_venda  dia_venda diferenca_dias  semestre_venda  \
# 227       2019          1          2       366 days               1
#
#      trimestre_venda
# 227                1

# %%
del df['semestre_venda']

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas  LojaID  Qtde lojaID  Receita  \
# 54    Salvador 2019-01-01   46.54    1037     3   1037   139.62
# 119    Aracaju 2018-01-01    9.32    1523     6   1523    55.92
# 131  Fortaleza 2019-03-02  139.07     982     6    982   834.42
# 19      Recife 2019-01-01  199.43     983     7    983  1396.01
# 22    Salvador 2019-01-01   32.57    1035     1   1035    32.57
#
#      Receita/Vendas  Ano_Venda  mes_venda  dia_venda diferenca_dias  \
# 54              3.0       2019          1          1       365 days
# 119             6.0       2018          1          1         0 days
# 131             6.0       2019          3          2       425 days
# 19              7.0       2019          1          1       365 days
# 22              1.0       2019          1          1       365 days
#
#      trimestre_venda
# 54                 1
# 119                1
# 131                1
# 19                 1
# 22                 1

# %%
#filtrando as vendas de 2019 do mes de marco
vendas_marco_19 = df.loc[(df["Data"].dt.year == 2019) & (df["Data"].dt.month == 3)]

# %%
vendas_marco_19.sample(20)
# Out:
#         Cidade       Data  Vendas  LojaID  Qtde lojaID  Receita  \
# 130     Recife 2019-03-02   12.36     983     4    983    49.44
# 124  Fortaleza 2019-03-02   47.98     983     7    983   335.86
# 141     Recife 2019-03-02  182.75     983     8    983  1462.00
# 116     Recife 2019-03-02   79.10     982     2    982   158.20
# 113   Salvador 2019-03-02   18.90    1034     3   1034    56.70
# 18       Natal 2019-03-14  581.00     853     3    853  1743.00
# 75       Natal 2019-03-30  706.00     854     2    854  1412.00
# 42       Natal 2019-03-02  775.00     854     2    854  1550.00
# 19       Natal 2019-03-31  282.00     854     2    854   564.00
# 130   Salvador 2019-03-02   59.78    1036     1   1036    59.78
# 132  Fortaleza 2019-03-02   17.49     983     5    983    87.45
# 5        Natal 2019-03-30  674.00     854     2    854  1348.00
# 117     Recife 2019-03-02   15.42     983     8    983   123.36
# 124   Salvador 2019-03-02   44.82    1034     3   1034   134.46
# 69       Natal 2019-03-24  817.00     852     4    852  3268.00
# 132     Recife 2019-03-02   17.49     983     5    983    87.45
# 117   Salvador 2019-03-02   39.41    1034     1   1034    39.41
# 117  Fortaleza 2019-03-02   15.42     983     8    983   123.36
# 114  Fortaleza 2019-03-02   16.82     983     4    983    67.28
# 133   Salvador 2019-03-02  153.71    1035     1   1035   153.71
#
#      Receita/Vendas  Ano_Venda  mes_venda  dia_venda diferenca_dias  \
# 130             4.0       2019          3          2       425 days
# 124             7.0       2019          3          2       425 days
# 141             8.0       2019          3          2       425 days
# 116             2.0       2019          3          2       425 days
# 113             3.0       2019          3          2       425 days
# 18              3.0       2019          3         14       437 days
# 75              2.0       2019          3         30       453 days
# 42              2.0       2019          3          2       425 days
# 19              2.0       2019          3         31       454 days
# 130             1.0       2019          3          2       425 days
# 132             5.0       2019          3          2       425 days
# 5               2.0       2019          3         30       453 days
# 117             8.0       2019          3          2       425 days
# 124             3.0       2019          3          2       425 days
# 69              4.0       2019          3         24       447 days
# 132             5.0       2019          3          2       425 days
# 117             1.0       2019          3          2       425 days
# 117             8.0       2019          3          2       425 days
# 114             4.0       2019          3          2       425 days
# 133             1.0       2019          3          2       425 days
#
#      trimestre_venda
# 130                1
# 124                1
# 141                1
# 116                1
# 113                1
# 18                 1
# 75                 1
# 42                 1
# 19                 1
# 130                1
# 132                1
# 5                  1
# 117                1
# 124                1
# 69                 1
# 132                1
# 117                1
# 117                1
# 114                1
# 133                1

# %%
df["LojaID"].value_counts (ascending = False)
# Out:
# 1036    117
# 1035    112
# 1037    101
# 1034     67
# 983      65
# 982      44
# 1522     41
# 1520     39
# 980      36
# 981      31
# 1005     30
# 1002     30
# 852      29
# 1523     29
# 1004     28
# 854      28
# 853      26
# 1521     21
# 1003     20
# Name: LojaID, dtype: int64

# %%
#gráfico de barras
df["LojaID"].value_counts (ascending = False).plot.bar()

# %%
#grafico barras horizontais
df["LojaID"].value_counts (ascending = False).plot.barh()

# %%
df["LojaID"].value_counts (ascending = True).plot.barh();

# %%
#grafico de pizza
df.groupby(df["Data"].dt.year)["Receita"].sum().plot.pie();

# %%
#Total de vendas por cidade
df["Cidade"].value_counts()
# Out:
# Natal        240
# Salvador     240
# Fortaleza    142
# Recife       142
# Aracaju      130
# Name: Cidade, dtype: int64

# %%
#adicionando um titulo e alterando o nome dos eixos
import matplotlib.pyplot as plt
df["Cidade"].value_counts().plot.bar(title="Total vendas por Cidade")
plt.xlabel("Cidade")
plt.ylabel("Total Vendas");

# %%
#alterando a cor
df["Cidade"].value_counts().plot.bar(title="Total vendas por Cidade", color="red")
plt.xlabel("Cidade")
plt.ylabel("Total Vendas");

# %%
#alterando o estilo
plt.style.use("ggplot")

# %%
df.groupby(df["mes_venda"])["Qtde"].sum().plot(title = "Total produtos vendidos por mes")
plt.xlabel("Mês")
plt.ylabel("Total Produtos Vendidos");
plt.legend();

# %%
df.groupby(df["mes_venda"])["Qtde"].sum()
# Out:
# mes_venda
# 1     2208
# 2      144
# 3      467
# 4       23
# 5       17
# 6       13
# 7       13
# 8        2
# 9       10
# 10      14
# 11       2
# 12       3
# Name: Qtde, dtype: int64

# %%
#selecionando apenas as vendas de 2019
df_2019 = df[df["Ano_Venda"] == 2019]

# %%
#total de produtos vendidos mes
df_2019.groupby(df_2019["mes_venda"])["Qtde"].sum().plot(marker = "*")
plt.xlabel("Mês")
plt.ylabel("Total Produtos Vendidos");
plt.legend();

# %%
plt.hist(df["Qtde"], color = "salmon");

# %%
plt.scatter(x=df_2019["dia_venda"], y = df_2019["Receita"]);

# %%
#salvando em png
df_2019.groupby(df_2019["mes_venda"])["Qtde"].sum().plot(marker = "v")
plt.title("Quantidade de produtos vendidos x mes")
plt.xlabel("Mês")
plt.ylabel("Total produtos vendidos");
plt.legend()
plt.savefig("grafico QTDE x MES.pdf")
